# %% [markdown]
# ## ECOMMERCE SALES ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
pd.read_excel(r"C:\Users\anand\Superstore.xlsx\Superstore.xlsx")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1          2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2          3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3          4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4          5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2011-110422 2011-01-22 2011-01-24    Second Class
# 9990    9991  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27 2014-03-04  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05 2014-05-10    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
csv=pd.read_excel(r"C:\Users\anand\Superstore.xlsx\Superstore.xlsx")

# %%
csv.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
csv.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2013-04-30 19:20:02.401441024
# min       1.000000            2011-01-04 00:00:00
# 25%    2499.250000            2012-05-23 00:00:00
# 50%    4997.500000            2013-06-27 00:00:00
# 75%    7495.750000            2014-05-15 00:00:00
# max    9994.000000            2014-12-31 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2013-05-04 18:20:49.229537792  55190.379428    229.858001     3.789574
# min              2011-01-08 00:00:00   1040.000000      0.444000     1.000000
# 25%              2012-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2013-06-30 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
des=csv.describe()

# %%
csv.sort_values(['Profit','Sales'],axis=0,ascending=[False,False],inplace=True)

# %%
fig=px.bar(csv.head(30),x="Region",y="Sales",color='Profit',hover_data=['Category'],width=700,title="Sales In Region")
fig.show()

# %%
fig=px.pie(csv.head(100),names='Sub-Category')
fig.show()

# %%
fig=px.bar(csv.head(100),x='Sub-Category',color='Category')
fig.show()

# %%
fig=px.pie(csv.head(100),names='Region')
fig.show()

# %%
fig=px.bar(csv.head(20),x="Customer Name",y="Quantity",color='Profit',hover_data=['Discount','Category'],width=700,height=600,title="Order Count of categories Sub-Category")
fig.show()

# %%
fig=px.pie(csv,names="Sub-Category",values='Profit',title="Order Count of categories Sub-Category")
fig.show()

# %%
csv.sort_values(['Sales'],axis=0,ascending=True,inplace=True)

# %%
fig=px.line(csv.head(20),x='Sales',y='Sub-Category')
fig.show()

# %%
sub=csv.loc[:,'Sub-Category']
sales=csv.loc[:,'Sales']
profit=csv.loc[:,'Profit]

fig=go.Figure()
\
